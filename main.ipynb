# %% [markdown]
# ### II.1

# %%
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np

# %% [markdown]
# ##### a)

# %% [markdown]
# ##### b)

# %% [markdown]
# ##### c)

# %% [markdown]
# ##### d)

# %% [markdown]
# ##### e)
